# %% [markdown]
# <a href="https://colab.research.google.com/github/nelsbuhrley/CSE-450-Machine-learning/blob/main/notebooks/Exploration_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Exploration 03
#
# You're working on an exhibit for a local museum called "The Titanic Disaster". They've asked you to analyze the passenger manifests and see if you can find any interesting information for the exhibit.
#
# The museum curator is particularly interested in why some people might have been more likely to survive than others.

# %% [markdown]
# ## Part 1: Import Pandas and load the data
#
# Remember to import Pandas the conventional way. If you've forgotten how, you may want to review [Data Exploration 01](https://byui-cse.github.io/cse450-course/module-01/exploration-01.html).
#
# The dataset for this exploration is stored at the following url:
#
# [https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/titanic.csv](https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/titanic.csv)
#
# There are lots of ways to load data into your workspace. The easiest way in this case is to [ask Pandas to do it for you](https://pandas.pydata.org/docs/getting_started/intro_tutorials/02_read_write.html).
#
# ### Initial Data Analysis
# Once you've loaded the data, it's a good idea to poke around a little bit to find out what you're dealing with.
#
# Some questions you might ask include:
#
# * What does the data look like?
# * What kind of data is in each column?
# * Do any of the columns have missing values?

# %%
# Part 1: Enter your code below to import Pandas according to the
# conventional method. Then load the dataset into a Pandas dataframe.

# Write any code needed to explore the data by seeing what the first few
# rows look like. Then display a technical summary of the data to determine
# the data types of each column, and which columns have missing data.

# %%
import polars as pl
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset into a Polars dataframe
df = pl.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/titanic.csv')
df = df.with_columns((pl.col('Survived') == 'Yes').alias('Survived'))
print(df.schema)
print(df.describe())
print(df.head())
df.head()
# Out:
# Schema({'PassengerId': Int64, 'Survived': Boolean, 'Pclass': Int64, 'Name': String, 'Sex': String, 'Age': Float64, 'SibSp': Int64, 'Parch': Int64, 'Ticket': String, 'Fare': Float64, 'Cabin': String, 'Embarked': String})
# shape: (9, 13)
# ┌────────────┬─────────────┬──────────┬──────────┬───┬───────────┬───────────┬───────┬──────────┐
# │ statistic  ┆ PassengerId ┆ Survived ┆ Pclass   ┆ … ┆ Ticket    ┆ Fare      ┆ Cabin ┆ Embarked │
# │ ---        ┆ ---         ┆ ---      ┆ ---      ┆   ┆ ---       ┆ ---       ┆ ---   ┆ ---      │
# │ str        ┆ f64         ┆ f64      ┆ f64      ┆   ┆ str       ┆ f64       ┆ str   ┆ str      │
# ╞════════════╪═════════════╪══════════╪══════════╪═══╪═══════════╪═══════════╪═══════╪══════════╡
# │ count      ┆ 891.0       ┆ 891.0    ┆ 891.0    ┆ … ┆ 891       ┆ 891.0     ┆ 204   ┆ 889      │
# │ null_count ┆ 0.0         ┆ 0.0      ┆ 0.0      ┆ … ┆ 0         ┆ 0.0       ┆ 687   ┆ 2        │
# │ mean       ┆ 446.0       ┆ 0.383838 ┆ 2.308642 ┆ … ┆ null      ┆ 32.204208 ┆ null  ┆ null     │
# │ std        ┆ 257.353842  ┆ null     ┆ 0.836071 ┆ … ┆ null      ┆ 49.693429 ┆ null  ┆ null     │
# │ min        ┆ 1.0         ┆ 0.0      ┆ 1.0      ┆ … ┆ 110152    ┆ 0.0       ┆ A10   ┆ C        │
# │ 25%        ┆ 224.0       ┆ null     ┆ 2.0      ┆ … ┆ null      ┆ 7.925     ┆ null  ┆ null     │
# │ 50%        ┆ 446.0       ┆ null     ┆ 3.0      ┆ … ┆ null      ┆ 14.4542   ┆ null  ┆ null     │
# │ 75%        ┆ 669.0       ┆ null     ┆ 3.0      ┆ … ┆ null      ┆ 31.0      ┆ null  ┆ null     │
# │ max        ┆ 891.0       ┆ 1.0      ┆ 3.0      ┆ … ┆ WE/P 5735 ┆ 512.3292  ┆ T     ┆ S        │
# └────────────┴─────────────┴──────────┴──────────┴───┴───────────┴───────────┴───────┴──────────┘
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬───────────────────┬───┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name              ┆ … ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---               ┆   ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ bool     ┆ i64    ┆ str               ┆   ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═══════════════════╪═══╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ false    ┆ 3      ┆ Braund, Mr. Owen  ┆ … ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris            ┆   ┆           ┆         ┆       ┆          │
# │ 2           ┆ true     ┆ 1      ┆ Cumings, Mrs.     ┆ … ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley (Fl… ┆   ┆           ┆         ┆       ┆          │
# │ 3           ┆ true     ┆ 3      ┆ Heikkinen, Miss.  ┆ … ┆ STON/O2.  ┆ 7.925   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina             ┆   ┆ 3101282   ┆         ┆       ┆          │
# │ 4           ┆ true     ┆ 1      ┆ Futrelle, Mrs.    ┆ … ┆ 113803    ┆ 53.1    ┆ C123  ┆ S        │
# │             ┆          ┆        ┆ Jacques Heath (…  ┆   ┆           ┆         ┆       ┆          │
# │ 5           ┆ false    ┆ 3      ┆ Allen, Mr.        ┆ … ┆ 373450    ┆ 8.05    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ William Henry     ┆   ┆           ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴───────────────────┴───┴───────────┴─────────┴───────┴──────────┘
# shape: (5, 12)
# ┌─────────────┬──────────┬────────┬───────────────────┬───┬───────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name              ┆ … ┆ Ticket    ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---               ┆   ┆ ---       ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ bool     ┆ i64    ┆ str               ┆   ┆ str       ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪═══════════════════╪═══╪═══════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ false    ┆ 3      ┆ Braund, Mr. Owen  ┆ … ┆ A/5 21171 ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris            ┆   ┆           ┆         ┆       ┆          │
# │ 2           ┆ true     ┆ 1      ┆ Cumings, Mrs.     ┆ … ┆ PC 17599  ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley (Fl… ┆   ┆           ┆         ┆       ┆          │
# │ 3           ┆ true     ┆ 3      ┆ Heikkinen, Miss.  ┆ … ┆ STON/O2.  ┆ 7.925   ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Laina             ┆   ┆ 3101282   ┆         ┆       ┆          │
# │ 4           ┆ true     ┆ 1      ┆ Futrelle, Mrs.    ┆ … ┆ 113803    ┆ 53.1    ┆ C123  ┆ S        │
# │             ┆          ┆        ┆ Jacques Heath (…  ┆   ┆           ┆         ┆       ┆          │
# │ 5           ┆ false    ┆ 3      ┆ Allen, Mr.        ┆ … ┆ 373450    ┆ 8.05    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ William Henry     ┆   ┆           ┆         ┆       ┆          │
# └─────────────┴──────────┴────────┴───────────────────┴───┴───────────┴─────────┴───────┴──────────┘

# %% [markdown]
# ## Part 2: Initial Exploration
#
# Using your visualization library of choice, let's first look at some features in isolation. Generate visualizations showing:
#
# - A comparison of the total number of passengers who survived compared to those that died.
# - A comparison of the total number of males compared to females
# - A histogram showing the distribution of sibling/spouse counts
# - A histogram showing the distribution of parent/child counts

# %%
# Part 2: # Write the code needed to generate the visualizations specified.

# Function that divides the data by a feature and calculates the percentage of the group that survived and didn't
def survival_statistics_by_feature(df, feature):
    '''
    This function takes in a dataframe and a feature and returns a dataframe with the survival percentage for each group of the feature.
    '''
    return df.group_by(feature).agg([
        (pl.col('Survived').mean() * 100).alias('Survived'),
        ((1 - pl.col('Survived')).mean() * 100).alias('Did_Not_Survive')
    ])

sns.histplot(data=df.to_pandas(), x='Age', hue='Survived', multiple='stack')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

sns.histplot(data=df.to_pandas(), x='Fare', hue='Survived', multiple='stack')
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

sns.countplot(data=df.to_pandas(), x='Pclass', hue='Survived')
plt.title('Survival Percentage by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['Yes', 'No'])
plt.show()

sns.countplot(data=df.to_pandas(), x='Survived')
plt.title('Survival')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

sns.countplot(data=df.to_pandas(), x='Sex')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

sns.histplot(data=df.to_pandas(), x='SibSp', hue='Survived', multiple='stack')
plt.title('Sibling/Spouse Distribution')
plt.xlabel('Number of Siblings/Spouses Aboard')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

sns.histplot(data=df.to_pandas(), x='Parch', hue='Survived', multiple='stack')
plt.title('Parent/Child Distribution')
plt.xlabel('Number of Parents/Children Aboard')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# ## Part 3: Pairwise Comparisons
# Use your visualization library of choice to look at how the survival distribution varied across different groups.
#
# - Choose some features that you think might have had some influence over the likelihood of a titanic passenger surviving.
#
# - For each of those features, generate a chart for each feature showing the survival distributions when taking that feature into account

# %%
# Write the code to explore how different features affect the survival distribution
import plotly.express as px
import plotly.graph_objects as go

# Calculate bin counts
df_clean = df.drop_nulls("Age")
bin_edges = list(range(0, 101, 5))
bin_data = df_clean.with_columns(
    bin=pl.col("Age").cut(breaks=bin_edges)
).group_by("bin").len().sort("bin")

bin_centers = [(bin_edges[i] + bin_edges[i+1])/2 for i in range(len(bin_edges)-1)]
bin_counts = bin_data["len"].to_list()

# Create histogram
fig = px.histogram(
    df_clean,
    x="Age",
    color="Survived",
    barnorm="percent",
    barmode="stack",
    title="Survival Percentage by Age Group",
)
fig.update_traces(xbins=dict(start=0, end=100, size=5))

# Add line chart for counts on secondary y-axis
fig.add_trace(
    go.Scatter(
        x=bin_centers,
        y=bin_counts,
        mode='lines+markers',
        name='Total Count',
        line=dict(color='black', width=3),
        yaxis="y2"
    )
)

# Configure dual y-axes
fig.update_layout(
    yaxis_title="Percentage (%)",
    yaxis2=dict(
        title="Total Passengers",
        overlaying="y",
        side="right"
    )
)
fig.show()

# Passenger Class visualization
fig = px.histogram(
    df.to_pandas(),
    x="Pclass",
    color="Survived",
    title="Survival Percentage by Passenger Class",
    barnorm="percent",
    barmode="stack"
)
fig.update_layout(yaxis_title="Percentage (%)", bargap=0.4)
fig.update_xaxes(tickvals=[1, 2, 3], ticktext=["1st Class", "2nd Class", "3rd Class"])
fig.show()

# Fare distribution by survival
fig = px.histogram(
    df.to_pandas(),
    x="Fare",
    color="Survived",
    title="Survival Percentage by Fare",
    barnorm="percent",
    barmode="stack"
)
fig.update_traces(xbins=dict(start=0, end=500, size=10))
fig.update_layout(yaxis_title="Percentage (%)")
fig.show()

# Fare distribution by Passenger Class
fig = px.histogram(
    df.to_pandas(),
    x="Fare",
    color="Pclass",
    title="Fare Distribution by Passenger Class",
)
fig.update_traces(xbins=dict(start=0, end=500, size=10))
fig.update_layout(yaxis_title="Count")
fig.show()

# Survival count by Gender
fig = px.bar(
    df.to_pandas().value_counts(['Survived', 'Sex']).reset_index(name='Count'),
    x='Survived',
    y='Count',
    color='Sex',
    title='Survival Count by Gender',
    labels={'Survived': 'Survived', 'Count': 'Count'},
    barmode='group'
)
fig.show()

# Gender and Survival breakdown
fig = px.bar(
    df.to_pandas().value_counts(['Sex', 'Survived']).reset_index(name='Count'),
    x='Sex',
    y='Count',
    color='Survived',
    title='Survival Percentage by Gender',
    labels={'Sex': 'Gender', 'Count': 'Count'},
    barmode='group',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b0f33818-c22f-431f-8154-cae4d6e8017a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0f33818-c22f-431f-8154-cae4d6e8017a")) {                    Plotly.newPlot(                        "b0f33818-c22f-431f-8154-cae4d6e8017a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Survived=False\u003cbr\u003eAge=%{x}\u003cbr\u003ecount (normalized as percent)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"x":[22.0,35.0,54.0,2.0,20.0,39.0,14.0,2.0,31.0,35.0,8.0,19.0,40.0,66.0,28.0,42.0,21.0,18.0,40.0,27.0,18.0,7.0,21.0,65.0,28.5,11.0,22.0,45.0,4.0,19.0,26.0,32.0,16.0,21.0,26.0,25.0,22.0,28.0,16.0,24.0,29.0,20.0,46.0,26.0,59.0,71.0,34.0,28.0,21.0,33.0,37.0,28.0,38.0,47.0,14.5,22.0,20.0,17.0,21.0,70.5,29.0,24.0,2.0,21.0,32.5,54.0,45.0,33.0,20.0,47.0,25.0,23.0,37.0,16.0,24.0,19.0,18.0,19.0,9.0,36.5,42.0,51.0,55.5,40.5,51.0,30.0,44.0,26.0,17.0,1.0,45.0,28.0,61.0,4.0,21.0,56.0,18.0,50.0,30.0,36.0,9.0,40.0,36.0,19.0,42.0,24.0,28.0,34.0,45.5,2.0,32.0,24.0,22.0,30.0,42.0,30.0,27.0,51.0,22.0,20.5,18.0,29.0,59.0,24.0,44.0,19.0,33.0,29.0,22.0,30.0,44.0,25.0,54.0,29.0,62.0,30.0,41.0,52.0,40.0,36.0,16.0,37.0,45.0,7.0,65.0,28.0,16.0,33.0,22.0,36.0,24.0,24.0,23.5,2.0,19.0,30.0,26.0,28.0,43.0,54.0,22.0,27.0,61.0,45.5,38.0,16.0,29.0,45.0,28.0,25.0,36.0,42.0,23.0,15.0,25.0,28.0,38.0,40.0,29.0,45.0,35.0,30.0,18.0,19.0,22.0,3.0,27.0,20.0,19.0,32.0,18.0,1.0,28.0,22.0,31.0,46.0,23.0,26.0,21.0,28.0,20.0,34.0,51.0,21.0,30.0,10.0,21.0,29.0,28.0,18.0,17.0,50.0,21.0,64.0,31.0,20.0,25.0,36.0,30.0,65.0,34.0,47.0,48.0,38.0,56.0,38.0,22.0,34.0,29.0,22.0,9.0,50.0,58.0,30.0,21.0,55.0,71.0,21.0,25.0,24.0,17.0,21.0,37.0,18.0,28.0,24.0,47.0,32.0,22.0,40.5,39.0,23.0,17.0,30.0,45.0,9.0,11.0,50.0,64.0,33.0,27.0,62.0,40.0,28.0,24.0,19.0,29.0,16.0,19.0,54.0,36.0,47.0,22.0,35.0,47.0,37.0,36.0,49.0,44.0,36.0,30.0,39.0,35.0,34.0,26.0,26.0,27.0,21.0,21.0,61.0,57.0,26.0,51.0,9.0,32.0,31.0,41.0,20.0,2.0,19.0,21.0,18.0,24.0,32.0,23.0,58.0,40.0,47.0,36.0,32.0,25.0,43.0,31.0,70.0,18.0,24.5,43.0,20.0,14.0,60.0,25.0,14.0,19.0,18.0,25.0,60.0,52.0,44.0,49.0,42.0,18.0,25.0,26.0,39.0,29.0,52.0,19.0,33.0,17.0,34.0,50.0,20.0,25.0,25.0,11.0,23.0,23.0,28.5,48.0,36.0,24.0,70.0,16.0,19.0,31.0,33.0,23.0,28.0,18.0,34.0,41.0,16.0,30.5,32.0,24.0,48.0,57.0,18.0,29.0,25.0,25.0,8.0,46.0,16.0,25.0,39.0,30.0,30.0,34.0,31.0,39.0,18.0,39.0,26.0,39.0,35.0,6.0,30.5,23.0,31.0,43.0,10.0,38.0,2.0,23.0,18.0,21.0,20.0,16.0,34.5,17.0,42.0,35.0,28.0,4.0,74.0,9.0,44.0,41.0,21.0,24.0,31.0,26.0,33.0,47.0,20.0,19.0,33.0,22.0,28.0,25.0,39.0,27.0,32.0],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":100,"size":5,"start":0}},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Survived=True\u003cbr\u003eAge=%{x}\u003cbr\u003ecount (normalized as percent)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"x":[38.0,26.0,35.0,27.0,14.0,4.0,58.0,55.0,34.0,15.0,28.0,38.0,14.0,3.0,19.0,49.0,29.0,21.0,5.0,38.0,29.0,17.0,32.0,0.83,30.0,29.0,17.0,33.0,23.0,23.0,34.0,21.0,32.5,12.0,24.0,29.0,19.0,22.0,24.0,27.0,22.0,16.0,40.0,9.0,1.0,1.0,4.0,45.0,32.0,19.0,3.0,44.0,58.0,18.0,26.0,16.0,40.0,35.0,31.0,27.0,32.0,16.0,38.0,19.0,35.0,5.0,8.0,24.0,37.0,29.0,30.0,35.0,50.0,3.0,25.0,58.0,35.0,25.0,41.0,63.0,35.0,19.0,30.0,42.0,22.0,26.0,19.0,50.0,0.92,17.0,30.0,24.0,18.0,26.0,24.0,31.0,40.0,30.0,22.0,36.0,36.0,31.0,16.0,41.0,45.0,2.0,24.0,24.0,40.0,3.0,22.0,60.0,24.0,25.0,22.0,42.0,1.0,35.0,36.0,17.0,36.0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90ae9d7b-fc0d-43b9-b782-9cfbe650dc69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90ae9d7b-fc0d-43b9-b782-9cfbe650dc69")) {                    Plotly.newPlot(                        "90ae9d7b-fc0d-43b9-b782-9cfbe650dc69",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Survived=False\u003cbr\u003ePclass=%{x}\u003cbr\u003ecount (normalized as percent)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"x":[3,3,3,1,3,3,3,3,3,3,2,3,3,1,3,1,2,1,1,3,3,3,2,3,3,3,3,3,3,3,1,3,3,3,1,3,1,3,3,2,3,2,3,3,3,3,3,1,3,3,3,3,3,1,3,3,3,1,2,3,3,1,3,3,3,3,1,3,3,3,3,3,3,2,1,3,2,3,2,1,3,3,3,3,3,2,2,1,3,1,3,3,2,2,3,2,2,2,3,3,3,1,3,3,3,3,3,3,3,3,1,3,1,3,3,1,3,3,1,2,3,3,2,3,1,3,3,2,3,3,2,3,3,3,3,3,3,3,3,2,3,2,2,2,3,3,3,3,2,3,3,2,2,3,2,2,2,3,2,3,3,1,3,2,3,3,1,3,3,3,1,1,3,2,3,1,1,3,2,3,3,3,3,1,3,3,2,3,3,1,3,1,3,3,2,2,3,2,2,3,3,3,3,1,1,3,3,1,1,2,2,2,3,3,1,3,3,3,3,2,3,2,3,3,3,3,3,3,1,3,1,3,3,3,3,2,3,3,3,3,3,2,2,3,3,3,3,2,3,3,3,3,3,2,3,2,3,3,3,3,3,3,3,3,3,1,3,1,2,3,3,2,3,1,3,1,3,3,1,2,3,3,2,1,3,3,3,3,1,2,3,3,3,2,3,3,1,3,3,3,1,1,3,3,3,1,3,3,3,3,3,1,3,3,3,1,3,3,3,3,3,3,1,3,2,3,3,3,1,3,3,3,1,1,3,2,3,1,1,3,3,2,3,3,3,3,3,3,3,3,3,2,1,3,2,3,3,3,3,3,2,3,3,3,3,1,3,3,3,3,3,3,3,3,3,2,3,3,3,1,2,3,3,3,1,3,3,2,3,3,3,3,3,3,3,3,3,2,3,3,2,1,3,1,3,2,2,3,3,1,2,2,3,3,3,3,3,3,2,2,3,3,3,3,1,2,3,1,3,3,3,3,2,1,3,2,3,3,3,3,2,2,3,2,3,3,2,2,2,3,3,3,3,1,3,1,3,1,3,3,3,3,2,3,3,3,3,1,3,3,3,3,3,2,3,3,3,3,1,3,3,3,3,1,3,2,3,1,3,2,3,3,2,3,1,3,2,3,3,2,3,3,1,3,2,3,3,1,3,3,3,3,3,3,3,3,3,2,3,3,3,3,3,2,3,3,3,2,3,3,2,3,2,1,3,3,1,3,3,3,3,3,3,2,3,3,2,3,3],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Survived=True\u003cbr\u003ePclass=%{x}\u003cbr\u003ecount (normalized as percent)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"x":[1,3,1,3,2,3,1,2,2,3,2,3,1,3,3,1,3,3,3,2,3,3,1,2,1,2,2,1,3,2,3,3,2,3,3,3,2,3,1,1,2,3,3,3,2,3,3,3,2,1,3,3,3,1,3,2,3,1,3,2,3,3,1,2,3,2,1,1,3,3,3,3,1,2,1,3,1,3,1,2,1,3,2,3,2,1,3,1,1,1,2,3,3,1,1,3,2,3,1,3,3,3,2,3,1,1,1,1,3,3,2,1,1,1,1,1,1,3,2,1,1,2,2,1,2,3,1,3,1,1,3,2,1,2,2,3,3,1,3,3,1,3,3,1,1,1,3,1,3,1,2,2,1,3,1,3,2,3,2,1,3,2,2,2,2,3,1,3,2,1,2,2,2,3,1,2,1,3,1,1,3,1,2,1,3,2,2,3,3,1,1,3,1,1,2,1,3,3,1,1,2,2,1,1,2,2,3,2,1,1,1,2,2,2,2,1,3,3,1,1,3,3,2,1,1,3,2,1,3,2,1,1,1,1,2,1,2,1,1,2,1,3,2,2,1,3,1,1,1,2,1,3,3,1,1,3,2,3,1,3,1,2,2,3,1,1,1,1,3,3,3,1,1,2,1,1,3,1,1,1,2,2,1,2,3,1,1,1,1,3,2,2,3,2,2,1,3,1,1,2,3,1,3,1,3,3,1,3,2,1,3,3,1,1,3,3,2,3,1,3,2,1,3,1,1,1,1,3,1,1,3,1,2,2,3,1,2,3,1,2,1,1],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"hea ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fcf0b379-1199-4eb5-ad8e-343f0d38ae57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcf0b379-1199-4eb5-ad8e-343f0d38ae57")) {                    Plotly.newPlot(                        "fcf0b379-1199-4eb5-ad8e-343f0d38ae57",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Survived=False\u003cbr\u003eFare=%{x}\u003cbr\u003ecount (normalized as percent)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"x":[7.25,8.05,8.4583,51.8625,21.075,8.05,31.275,7.8542,29.125,18.0,26.0,21.075,7.225,263.0,7.8958,27.7208,10.5,82.1708,52.0,8.05,18.0,9.475,21.0,7.8958,8.05,15.5,21.6792,17.8,39.6875,7.8,61.9792,7.2292,46.9,7.2292,83.475,27.9,27.7208,8.1583,8.6625,10.5,46.9,73.5,14.4542,7.65,7.8958,8.05,9.0,47.1,34.375,8.05,8.05,8.05,7.8542,61.175,20.575,7.25,8.05,34.6542,26.0,7.8958,7.8958,77.2875,8.6542,7.925,7.8958,7.8958,52.0,14.4542,8.05,9.825,14.4583,7.925,7.75,21.0,247.5208,31.275,73.5,8.05,30.0708,77.2875,7.75,6.975,7.8958,7.05,14.5,13.0,15.0458,53.1,9.2167,79.2,15.2458,6.75,11.5,36.75,34.375,26.0,13.0,12.525,8.05,14.5,7.3125,61.3792,8.05,8.6625,69.55,16.1,7.775,8.6625,39.6875,27.9,25.925,56.4958,33.5,29.125,7.925,30.6958,7.8542,25.4667,28.7125,13.0,0.0,69.55,15.05,31.3875,50.0,15.5,7.8958,13.0,7.75,8.4042,13.0,9.5,69.55,6.4958,7.225,10.4625,15.85,7.05,7.25,13.0,7.75,27.0,10.5,13.0,8.05,7.8958,9.35,7.25,13.0,25.4667,7.775,13.5,10.5,7.55,26.0,10.5,12.275,14.4542,10.5,7.125,7.225,90.0,7.775,26.0,7.25,10.4625,26.55,16.1,20.2125,7.75,79.65,0.0,7.75,10.5,39.6875,31.0,29.7,7.75,0.0,29.125,7.75,7.8542,9.5,26.0,8.6625,7.8958,12.875,8.85,7.8958,27.7208,7.2292,151.55,0.0,8.05,24.0,26.0,7.8958,26.25,14.0,7.25,7.8958,69.55,6.2375,28.5,153.4625,18.0,7.8958,66.6,35.5,13.0,13.0,13.0,8.6625,9.225,35.0,7.2292,17.8,7.225,9.5,13.0,27.9,27.7208,14.4542,7.05,15.5,7.25,6.4958,8.05,135.6333,21.075,211.5,4.0125,7.775,7.925,7.8958,73.5,46.9,7.7292,7.925,7.7958,7.8542,26.0,10.5,8.05,9.825,15.85,8.6625,21.0,7.75,7.775,25.4667,7.8958,6.8583,0.0,8.05,13.0,24.15,7.8958,7.7333,7.875,14.4,20.2125,7.25,7.75,7.125,55.9,34.375,263.0,10.5,9.5,7.775,27.75,19.9667,27.75,8.05,26.55,7.75,8.05,38.5,13.0,8.05,7.05,0.0,26.55,7.725,7.25,8.6625,9.8375,52.0,21.0,7.0458,7.5208,46.9,0.0,8.05,25.4667,29.7,8.05,19.9667,7.25,30.5,49.5042,8.05,14.4583,15.1,151.55,7.7958,8.6625,7.75,7.6292,9.5875,108.9,22.525,8.05,7.4958,34.0208,24.15,7.8958,7.8958,7.225,7.2292,7.75,221.7792,7.925,11.5,7.2292,7.2292,8.6625,26.55,14.5,31.275,31.275,106.425,26.0,20.525,26.0,7.8292,26.55,227.525,7.75,7.8958,13.5,8.05,8.05,24.15,7.8958,21.075,7.2292,8.05,14.5,14.4583,26.0,40.125,8.7125,15.0,8.05,8.05,7.125,7.25,7.75,26.0,24.15,0.0,7.225,7.8958,42.4,8.05,15.55,7.8958,31.275,7.05,7.75,8.05,14.4,16.1,10.5,14.4542,7.8542,16.1,32.3208,12.35,7.8958,7.7333,7.0542,0.0,27.9,7.925,26.25,39.6875,16.1,7.8542,27.9,7.8958,7.55,7.8958,8.4333,6.75,73.5,7.8958,15.5,13.0,113.275,7.225,25.5875,7.4958,73.5,13.0,7.775,8.05,52.0,10.5,0.0,7.775,8.05,46.9,8.1375,9.225,46.9,39.0,41.5792,39.6875,10.1708,7.7958,7.225,26.55,13.5,8.05,110.8833,7.65,14.4542,7.7417,7.8542,26.0,26.55,9.4833,13.0,7.65,15.5,7.775,7.0542,13.0,13.0,8.6625,26.0,7.925,18.7875,0.0,13.0,13.0,16.1,34.375,7.8958,7.8958,78.85,16.1,71.0,20.25,53.1,7.75,9.5,7.8958,7.7958,11.5,8.05,14.5,7.125,7.775,39.6,7.75,24.15,8.3625,9.5,7.8542,10.5,7.225,7.75,7.75,7.7375,30.0,23.45,7.05,7.25,29.125,79.2,7.75,26.0,69.55,30.6958,7.8958,13.0,7.2292,24.15,13.0,7.775,0.0,7.775,13.0,7.8875,24.15,10.5,31.275,8.05,0.0,7.925,37.0042,6.45,27.9,0.0,39.6875,6.95,56.4958,7.2292,7.8542,8.3,8.6625,8.05,7.925,10.5,6.43 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="924a3fd5-06d3-427b-8c3a-c0542bf93c17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("924a3fd5-06d3-427b-8c3a-c0542bf93c17")) {                    Plotly.newPlot(                        "924a3fd5-06d3-427b-8c3a-c0542bf93c17",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Pclass=3\u003cbr\u003eFare=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"3","offsetgroup":"3","orientation":"v","showlegend":true,"x":[7.25,7.925,8.05,8.4583,21.075,11.1333,16.7,8.05,31.275,7.8542,29.125,18.0,7.225,8.0292,21.075,31.3875,7.225,7.8792,7.8958,7.75,7.2292,8.05,18.0,11.2417,9.475,7.8958,7.8792,8.05,15.5,7.75,21.6792,17.8,39.6875,7.8,7.2292,46.9,7.2292,27.9,15.2458,8.1583,7.925,8.6625,46.9,14.4542,56.4958,7.65,7.8958,8.05,12.475,9.0,9.5,7.7875,15.85,34.375,8.05,8.05,8.05,7.8542,20.575,7.25,8.05,7.8958,7.8958,8.6542,7.925,7.8958,7.65,7.775,7.8958,24.15,14.4542,8.05,9.825,14.4583,7.925,7.75,31.275,8.05,11.2417,7.75,7.1417,22.3583,6.975,7.8958,7.05,14.5,9.2167,15.2458,7.75,15.85,6.75,7.7958,34.375,8.05,14.5,7.3125,7.7333,8.05,8.6625,69.55,16.1,7.775,8.6625,39.6875,20.525,27.9,56.4958,29.125,11.1333,7.925,7.8542,25.4667,0.0,69.55,31.3875,22.025,15.5,15.5,7.8958,7.8542,7.75,8.4042,7.75,9.5,69.55,6.4958,7.225,8.05,10.4625,15.85,18.7875,7.75,7.05,7.25,7.75,7.925,8.05,8.05,7.8958,9.35,7.25,25.4667,7.775,31.3875,7.55,14.4542,15.5,7.125,7.225,7.775,7.25,10.4625,16.1,20.2125,15.2458,7.75,31.3875,7.75,39.6875,7.775,0.0,7.75,7.75,29.125,20.25,7.75,7.8542,9.5,8.05,8.6625,9.5,7.8958,7.75,8.85,7.8958,7.2292,7.75,23.25,0.0,8.05,7.8958,7.8542,7.25,7.8958,69.55,6.2375,20.525,23.25,18.0,7.8958,8.05,16.1,15.9,8.6625,9.225,7.2292,17.8,7.225,9.5,7.8792,7.8792,27.9,14.4542,7.05,15.5,7.25,7.2292,7.75,6.4958,8.05,21.075,7.25,4.0125,7.775,15.7417,7.925,7.8958,46.9,7.7292,7.7958,7.925,16.7,7.7958,7.8542,7.925,8.05,9.825,15.85,8.6625,7.75,7.775,25.4667,7.8958,6.8583,7.925,8.05,24.15,7.8958,7.7333,7.875,14.4,20.2125,7.25,7.75,8.05,16.1,7.125,34.375,9.5,7.775,8.1125,19.2583,19.9667,8.05,7.8958,7.75,8.05,8.05,7.05,7.725,19.2583,7.25,8.6625,9.8375,7.0458,7.5208,12.2875,46.9,8.05,9.5875,25.4667,8.05,15.9,19.9667,7.25,8.05,14.4583,15.1,7.7958,8.6625,7.75,7.6292,9.5875,22.525,56.4958,7.75,8.05,7.4958,24.15,7.8958,7.8958,7.225,7.2292,7.75,7.925,7.2292,7.2292,22.3583,8.6625,14.5,31.275,31.275,20.525,7.8292,7.225,7.775,17.4,7.75,7.8958,8.05,8.05,24.15,7.8958,21.075,7.2292,7.8542,7.75,8.05,14.5,14.4583,7.925,8.7125,8.05,8.05,7.125,7.25,7.75,24.15,0.0,7.225,7.8958,8.05,15.55,7.8958,31.275,7.05,15.5,7.75,8.05,14.4,16.1,14.4542,15.7417,7.8542,16.1,7.8958,7.7333,7.0542,27.9,7.925,39.6875,16.1,7.8542,27.9,56.4958,19.2583,7.8958,7.55,7.55,7.8958,8.4333,7.8292,6.75,7.8958,15.5,7.225,7.4958,7.925,7.775,8.05,7.775,8.05,9.8417,46.9,8.1375,9.225,46.9,39.6875,10.1708,7.7958,13.4167,56.4958,7.225,8.05,7.7333,7.65,14.4542,7.7417,7.8542,15.2458,9.4833,7.65,15.5,7.775,7.0542,8.6625,7.7375,7.925,18.7875,16.1,34.375,7.8958,7.8958,16.1,7.925,20.25,7.75,12.475,9.5,7.8958,7.7958,8.05,14.5,7.125,7.2292,7.775,7.75,24.15,8.3625,9.5,7.8542,7.225,7.75,7.75,12.475,7.7375,7.2292,23.45,7.05,7.25,7.4958,29.125,20.575,7.75,69.55,7.8958,8.6833,7.2292,24.15,8.5167,6.975,7.775,7.775,7.8875,24.15,31.275,8.05,7.925,6.45,27.9,8.6625,12.475,39.6875,6.95,56.4958,7.75,14.4542,7.2292,7.8542,8.3,8.6625,8.05,56.4958,7.925,6.4375,8.6625,7.55,69.55,7.8958,31.275,7.775,15.2458,9.35,19.2583,7.2292,14.1083,69.55,9.5,11.1333,7.8958,9.0,7.225,9.8458,7.8958,7.8958,7.8958,10.5167,7.05,29.125,23.45,7.75],"xaxis":"x","yaxis":"y","type":"histogram","xbins":{"end":500,"size":10,"start":0}},{"alignment ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="28357668-34e2-4aa7-8e0e-c0cbe27d1794" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28357668-34e2-4aa7-8e0e-c0cbe27d1794")) {                    Plotly.newPlot(                        "28357668-34e2-4aa7-8e0e-c0cbe27d1794",                        [{"alignmentgroup":"True","hovertemplate":"Sex=male\u003cbr\u003eSurvived=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"male","offsetgroup":"male","orientation":"v","showlegend":true,"textposition":"auto","x":[false,true],"xaxis":"x","y":[468,109],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sex=female\u003cbr\u003eSurvived=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"textposition":"auto","x":[true,false],"xaxis":"x","y":[233,81],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="900ff417-05db-42db-8c28-eb48fae05b66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("900ff417-05db-42db-8c28-eb48fae05b66")) {                    Plotly.newPlot(                        "900ff417-05db-42db-8c28-eb48fae05b66",                        [{"alignmentgroup":"True","hovertemplate":"Survived=False\u003cbr\u003eGender=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"textposition":"auto","x":["male","female"],"xaxis":"x","y":[468,81],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Survived=True\u003cbr\u003eGender=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"textposition":"auto","x":["female","male"],"xaxis":"x","y":[233,109],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{" ...

# %% [markdown]
# ## Part 4: Feature Engineering
#
# The museum curator wonders if the passenger's rank and title might have anything to do with whether or not they survived. Since this information is embedded in their name, we'll use "feature engineering" to create two new columns:
#
# - Title: The passenger's title
# - Rank: A boolean (true/false) indicating if a passenger was someone of rank.
#
# For the first new column, you'll need to find a way to [extract the title portion of their name](https://pandas.pydata.org/docs/getting_started/intro_tutorials/10_text_data.html). Be sure to clean up any whitespace or extra punctuation.
#
# For the second new column, you'll need to first look at a summary of your list of titles and decide what exactly constitutes a title of rank. Will you include military and eccelsiastical titles? Once you've made your decision, create the second column.
#
# You may want to review prior Data Explorations for tips on creating new columns and checking for lists of values.

# %%
# Titles: Mr. Mrs. Miss. Master. Mme. Mlle. Dr. Rev. Col. Don. Ms. Capt. Jonkheer. Countess. Major. Lady. Sir.

df = df.with_columns(
    pl.when(pl.col('Name').str.contains(r'Mrs\.')).then(pl.lit('Mrs.'))
    .when(pl.col('Name').str.contains(r'Miss\.')).then(pl.lit('Miss.'))
    .when(pl.col('Name').str.contains(r'Master\.')).then(pl.lit('Master.'))
    .when(pl.col('Name').str.contains(r'Mme\.')).then(pl.lit('Mme.'))
    .when(pl.col('Name').str.contains(r'Mlle\.')).then(pl.lit('Mlle.'))
    .when(pl.col('Name').str.contains(r'Ms\.')).then(pl.lit('Ms.'))
    .when(pl.col('Name').str.contains(r'Mr\.')).then(pl.lit('Mr.'))
    .when(pl.col('Name').str.contains(r'Dr\.')).then(pl.lit('Dr.'))
    .when(pl.col('Name').str.contains(r'Rev\.')).then(pl.lit('Rev.'))
    .when(pl.col('Name').str.contains(r'Col\.')).then(pl.lit('Col.'))
    .when(pl.col('Name').str.contains(r'Don\.')).then(pl.lit('Don.'))
    .when(pl.col('Name').str.contains(r'Capt\.')).then(pl.lit('Capt.'))
    .when(pl.col('Name').str.contains(r'Jonkheer\.')).then(pl.lit('Jonkheer.'))
    .when(pl.col('Name').str.contains(r'Countess\.')).then(pl.lit('Countess.'))
    .when(pl.col('Name').str.contains(r'Major\.')).then(pl.lit('Major.'))
    .when(pl.col('Name').str.contains(r'Lady\.')).then(pl.lit('Lady.'))
    .when(pl.col('Name').str.contains(r'Sir\.')).then(pl.lit('Sir.'))
    .otherwise(pl.lit('Other')).alias('Title')
)

df = df.with_columns(
    pl.when(pl.col('Title').is_in(['Mr.', 'Mrs.', 'Miss.', 'Master.', 'Ms.', 'Mme.', 'Mlle.'])).then(pl.lit('Common'))
    .when(pl.col('Title').is_in(['Col.', 'Major.', 'Capt.'])).then(pl.lit('Military'))
    .when(pl.col('Title').is_in(['Dr.', 'Rev.'])).then(pl.lit('Professional'))
    .when(pl.col('Title').is_in(['Jonkheer.', 'Countess.', 'Lady.', 'Sir.', 'Don.'])).then(pl.lit('Nobility'))
    .otherwise(pl.col('Title')).alias('Title_Class')
)

with pl.Config(tbl_rows=-1):
    print(df.select('Title').unique().sort('Title'))
    print(df.select('Title_Class').unique().sort('Title_Class'))
# Out:
# shape: (17, 1)
# ┌───────────┐
# │ Title     │
# │ ---       │
# │ str       │
# ╞═══════════╡
# │ Capt.     │
# │ Col.      │
# │ Countess. │
# │ Don.      │
# │ Dr.       │
# │ Jonkheer. │
# │ Lady.     │
# │ Major.    │
# │ Master.   │
# │ Miss.     │
# │ Mlle.     │
# │ Mme.      │
# │ Mr.       │
# │ Mrs.      │
# │ Ms.       │
# │ Rev.      │
# │ Sir.      │
# └───────────┘
# shape: (4, 1)
# ┌──────────────┐
# │ Title_Class  │
# │ ---          │
# │ str          │
# ╞══════════════╡
# │ Common       │
# │ Military     │
# │ Nobility     │
# │ Professional │
# └──────────────┘

# %% [markdown]
# ### Revisit Visualizations
# Now that you have the new columns in place. Revisit the pairwise comparison plots to see if the new columns reveal any interesting relationships.

# %%
# Enter the code needed to recheck the pairwise comparison.
counts = df.to_pandas().groupby(['Title_Class', 'Survived']).size().reset_index(name='Count')
counts['Percentage'] = counts.groupby('Title_Class')['Count'].transform(lambda x: x / x.sum() * 100)


total_counts_class = df.group_by('Title_Class').agg(pl.len().alias('Total'))
total_counts_title = df.group_by('Title').agg(pl.len().alias('Total'))

print(total_counts_class)
print(total_counts_title)

fig = px.bar(
    counts,
    x='Title_Class',
    y='Percentage',
    color='Survived',
    title='Survival Rate by Title Class',
    labels={'Title_Class': 'Title Class', 'Percentage': 'Percentage (%)'},
    barmode='stack',
)
fig.show()

counts = df.to_pandas().groupby(['Title', 'Survived']).size().reset_index(name='Count')
counts['Percentage'] = counts.groupby('Title')['Count'].transform(lambda x: x / x.sum() * 100)

fig = px.bar(
    counts,
    x='Title',
    y='Percentage',
    color='Survived',
    title='Survival Rate by Title',
    labels={'Title': 'Title', 'Percentage': 'Percentage (%)'},
    barmode='stack',
)
fig.show()
# Out:
# shape: (4, 2)
# ┌──────────────┬───────┐
# │ Title_Class  ┆ Total │
# │ ---          ┆ ---   │
# │ str          ┆ u32   │
# ╞══════════════╪═══════╡
# │ Nobility     ┆ 5     │
# │ Military     ┆ 5     │
# │ Common       ┆ 868   │
# │ Professional ┆ 13    │
# └──────────────┴───────┘
# shape: (17, 2)
# ┌───────────┬───────┐
# │ Title     ┆ Total │
# │ ---       ┆ ---   │
# │ str       ┆ u32   │
# ╞═══════════╪═══════╡
# │ Dr.       ┆ 7     │
# │ Sir.      ┆ 1     │
# │ Miss.     ┆ 182   │
# │ Capt.     ┆ 1     │
# │ Mr.       ┆ 517   │
# │ …         ┆ …     │
# │ Jonkheer. ┆ 1     │
# │ Ms.       ┆ 1     │
# │ Lady.     ┆ 1     │
# │ Countess. ┆ 1     │
# │ Mlle.     ┆ 2     │
# └───────────┴───────┘
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4dc5da9b-e908-4529-8e3c-5cbf947efdef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dc5da9b-e908-4529-8e3c-5cbf947efdef")) {                    Plotly.newPlot(                        "4dc5da9b-e908-4529-8e3c-5cbf947efdef",                        [{"alignmentgroup":"True","hovertemplate":"Survived=False\u003cbr\u003eTitle Class=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"textposition":"auto","x":["Common","Military","Nobility","Professional"],"xaxis":"x","y":[61.52073732718893,60.0,40.0,76.92307692307693],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Survived=True\u003cbr\u003eTitle Class=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"textposition":"auto","x":["Common","Military","Nobility","Professional"],"xaxis":"x","y":[38.47926267281106,40.0,60.0,23.076923076923077],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidt ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a875e81d-df3e-44d7-842c-8711e565b81f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a875e81d-df3e-44d7-842c-8711e565b81f")) {                    Plotly.newPlot(                        "a875e81d-df3e-44d7-842c-8711e565b81f",                        [{"alignmentgroup":"True","hovertemplate":"Survived=False\u003cbr\u003eTitle=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"textposition":"auto","x":["Capt.","Col.","Don.","Dr.","Jonkheer.","Major.","Master.","Miss.","Mr.","Mrs.","Rev."],"xaxis":"x","y":[100.0,50.0,100.0,57.14285714285714,100.0,50.0,42.5,30.21978021978022,84.33268858800773,20.8,100.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Survived=True\u003cbr\u003eTitle=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"textposition":"auto","x":["Col.","Countess.","Dr.","Lady.","Major.","Master.","Miss.","Mlle.","Mme.","Mr.","Mrs.","Ms.","Sir."],"xaxis":"x","y":[50.0,100.0,42.857142857142854,100.0,50.0,57.49999999999999,69.78021978021978,100.0,100.0,15.667311411992262,79.2,100.0,100.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...

# %% [markdown]
# ## Part 5: Encoding
#
# The museum has partnered with a data science group to build some interactive predicitive models using the titanic passenger data.
#
# Many machine learning algorithms require categorical features to be **encoded** as numbers.
#
# There are two approaches to this, label encoding (sometimes called factorization), and "one-hot" encoding.
#
# ### Label Encoding
#
# Label encoding creates numeric labels for each categorical value. For example, imagine we have a feature in the data called `Pet` with these values for the first five rows: `['Dog', 'Cat', 'Dog', 'Dog', 'Bird']`.
#
# We could create a new feature called `Pet_Encoded` where those values are represented as: `[0, 1, 0, 0, 2]`. Where `0 = Dog, 1 = Cat, and 2 = Bird`.
#
# In pandas there are two common ways to label encode a feature:
#
# #### Method 1: factorize()
#
# First, we could pandas' [factorize() method](https://pandas.pydata.org/docs/reference/api/pandas.factorize.html). It takes the series you want to encode as an argument and returns a list of two items.
#
# The first item is an array of encoded values. The second is the set of original values.
#
#
#     # The factorize() method returns the new values and the originals in a list.
#     # So the [0] at the end indicates we want only the new values.
#     myData['Pet_Encoded'] = pd.factorize(myData['Pet'])[0]
#
#
# #### Method 2: Category Data Type
# Every column in a pandas dataframe is a certain datatype. Usually, pandas infers which datatype to use based on the values of the column. However, we can use the `astype()` method to convert a feature from one type to another.
#
# If we first convert a feature to the `category` datatype, we can ask pandas to create a new column in the data frame based on the category codes:
#
#     # Convert our column to the category type
#     myData['Pet'] = myData['Pet'].astype('category')
#     myData['Pet_Encoded'] = myData['Pet'].cat.codes
#
#
# Whichever method we choose, our machine learning algorithm could use the new `Pet_Encoded` feature in place of the `Pet` feature.

# %%
# Label encode Sex column using Polars ordinal encoding
df = df.with_columns(
    pl.col('Sex').cast(pl.Categorical).cast(pl.Int32).alias('Sex_Encoded')
)
print(df.select('Sex_Encoded').unique().sort('Sex_Encoded'), df.select('Sex').unique().sort('Sex'))
# Out:
# shape: (2, 1)
# ┌─────────────┐
# │ Sex_Encoded │
# │ ---         │
# │ i32         │
# ╞═════════════╡
# │ 16          │
# │ 17          │
# └─────────────┘ shape: (2, 1)
# ┌────────┐
# │ Sex    │
# │ ---    │
# │ str    │
# ╞════════╡
# │ female │
# │ male   │
# └────────┘

# %% [markdown]
# ### One-Hot Encoding
#
# One problem with label encoding is that it can make a categorical variable appear as if it contains a quantitative relationship between its values.
#
# In the example above, is Bird twice as important as Cat? Some algorithms might interpret those values that way.
#
# One-Hot encoding avoids this problem by creating a new feature for each category. The value of the new feature is either `0` (is not this value) or `1` (is this value).
#
# In pandas, we can use the [get_dummies()](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html) method to deal with this problem:
#
#     myEncodedData = pd.get_dummies(myData, columns=['Pet'])
#
# In the case of our `Pet` example, the new features created by `get_dummies()` would be:
#
# | Pet_is_Dog | Pet_is_Cat | Pet_is_Bird |
# |:----------:|:----------:|:-----------:|
# |      1     |      0     |      0      |
# |      0     |      1     |      0      |
# |      1     |      0     |      0      |
# |      1     |      0     |      0      |
# |      0     |      0     |      1      |
#
# Notice that for our data, if `Pet_is_Bird` = 0 and `Pet_is_Cat` = 0, we know that the pet has to be a dog. So the `Pet_is_Dog` column contains redundant information. When this happens, we say that our data contains a _multicollinearity_ problem.
#
# To avoid this, we can tell `get_dummies()` that we want to get rid of one of the columns using the `drop_first` parameter:
#
#     myEncodedData = pd.get_dummies(myData, columns=['Pet'], drop_first=True)
#
# The main disadvantage to One-Hot encoding is that if the feature you're encoding has a lot of different values, it can result in a lot of extra features. This can sometimes lead to poor performance with some types of algorithms.

# %%
# Use the pandas get_dummies() method to one-hot encode the Embarked column.
df = df.to_dummies(columns=['Embarked'], drop_first=True)
df.head()
# Out:
# shape: (5, 17)
# ┌─────────────┬──────────┬────────┬─────────────┬───┬────────────┬───────┬────────────┬────────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name        ┆ … ┆ Embarked_n ┆ Title ┆ Title_Clas ┆ Sex_Encode │
# │ ---         ┆ ---      ┆ ---    ┆ ---         ┆   ┆ ull        ┆ ---   ┆ s          ┆ d          │
# │ i64         ┆ bool     ┆ i64    ┆ str         ┆   ┆ ---        ┆ str   ┆ ---        ┆ ---        │
# │             ┆          ┆        ┆             ┆   ┆ u8         ┆       ┆ str        ┆ i32        │
# ╞═════════════╪══════════╪════════╪═════════════╪═══╪════════════╪═══════╪════════════╪════════════╡
# │ 1           ┆ false    ┆ 3      ┆ Braund, Mr. ┆ … ┆ 0          ┆ Mr.   ┆ Common     ┆ 16         │
# │             ┆          ┆        ┆ Owen Harris ┆   ┆            ┆       ┆            ┆            │
# │ 2           ┆ true     ┆ 1      ┆ Cumings,    ┆ … ┆ 0          ┆ Mrs.  ┆ Common     ┆ 17         │
# │             ┆          ┆        ┆ Mrs. John   ┆   ┆            ┆       ┆            ┆            │
# │             ┆          ┆        ┆ Bradley     ┆   ┆            ┆       ┆            ┆            │
# │             ┆          ┆        ┆ (Fl…        ┆   ┆            ┆       ┆            ┆            │
# │ 3           ┆ true     ┆ 3      ┆ Heikkinen,  ┆ … ┆ 0          ┆ Miss. ┆ Common     ┆ 17         │
# │             ┆          ┆        ┆ Miss. Laina ┆   ┆            ┆       ┆            ┆            │
# │ 4           ┆ true     ┆ 1      ┆ Futrelle,   ┆ … ┆ 0          ┆ Mrs.  ┆ Common     ┆ 17         │
# │             ┆          ┆        ┆ Mrs.        ┆   ┆            ┆       ┆            ┆            │
# │             ┆          ┆        ┆ Jacques     ┆   ┆            ┆       ┆            ┆            │
# │             ┆          ┆        ┆ Heath (…    ┆   ┆            ┆       ┆            ┆            │
# │ 5           ┆ false    ┆ 3      ┆ Allen, Mr.  ┆ … ┆ 0          ┆ Mr.   ┆ Common     ┆ 16         │
# │             ┆          ┆        ┆ William     ┆   ┆            ┆       ┆            ┆            │
# │             ┆          ┆        ┆ Henry       ┆   ┆            ┆       ┆            ┆            │
# └─────────────┴──────────┴────────┴─────────────┴───┴────────────┴───────┴────────────┴────────────┘

# %% [markdown]
# ## Part 6: Conclusions
#
# Based on your analysis, what interesting relationships did you find? Write three interesting facts the museum can use in their exhibit.

# %% [markdown]
# ## Valueable relationships
# **Gender**
# - Male Passengers Are more likely to die than female passengers
# **Wealth/Status/Class**
# - There are a number of ways to measure this but people with people in first class, and people who paid a lot are more likely to survive, Further study should be done into that relationship
# - Title is not a valid indicator because of the incredibly small sample size of people with noble, professional and military titles. Even if you combine all of them n=23. And if you change where a title belongs (Don as a example), it changes the statistics dramatically
# **Age**
# - The older a passenger was the more likely they were to die, their chances of survival drop rapidly as you approach 65 years old (The sample size is quite small there though)

# %% [markdown]
# ## 🌟 Above and Beyond 🌟
#
# 1. There appears to be a lot of different variations of similar titles. (such as abbreviations for Miss and Mademoiselle).
#
#    Scan through the different titles to see which titles can be consolidated, then use what you know about data manipulation to simplify the distribution.
#
#    Once you've finished, check the visualizations again to see if that made any difference.
#
# 2. The museum curator has room for a couple of nice visualizations for the exhibit. Create additional visualizations that are suitable for public display.

# %%
# Clasify titles into common male, common female, military, professional, and nobility male and nobility female

df = df.with_columns(
    pl.when(pl.col('Title').is_in(['Mr.', 'Master.'])).then(pl.lit('Common_Male'))
    .when(pl.col('Title').is_in(['Mrs.', 'Ms.', 'Mme.', 'Mlle.', 'Miss.'])).then(pl.lit('Common_Female'))
    .when(pl.col('Title').is_in(['Col.', 'Major.', 'Capt.'])).then(pl.lit('Military'))
    .when(pl.col('Title').is_in(['Dr.', 'Rev.'])).then(pl.lit('Professional'))
    .when(pl.col('Title').is_in(['Jonkheer.', 'Sir.', 'Don.'])).then(pl.lit('Nobility_Male'))
    .when(pl.col('Title').is_in(['Countess.', 'Lady.'])).then(pl.lit('Nobility_Female'))
    .otherwise(pl.col('Title')).alias('Title_Class_Gendered')
)

counts = df.to_pandas().groupby(['Title_Class_Gendered', 'Survived']).size().reset_index(name='Count')
counts['Percentage'] = counts.groupby('Title_Class_Gendered')['Count'].transform(lambda x: x / x.sum() * 100)

fig = px.bar(
    counts,
    x='Title_Class_Gendered',
    y='Percentage',
    color='Survived',
    title='Survival Rate by Title',
    labels={'Title_Class_Gendered': 'Title Class', 'Percentage': 'Percentage (%)'},
    barmode='stack',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5be8f533-9f1c-4cf0-9549-0a19b0ca3a37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5be8f533-9f1c-4cf0-9549-0a19b0ca3a37")) {                    Plotly.newPlot(                        "5be8f533-9f1c-4cf0-9549-0a19b0ca3a37",                        [{"alignmentgroup":"True","hovertemplate":"Survived=False\u003cbr\u003eTitle Class=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"textposition":"auto","x":["Common_Female","Common_Male","Military","Nobility_Male","Professional"],"xaxis":"x","y":[26.04501607717042,81.32854578096948,60.0,66.66666666666666,76.92307692307693],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Survived=True\u003cbr\u003eTitle Class=%{x}\u003cbr\u003ePercentage (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"True","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"textposition":"auto","x":["Common_Female","Common_Male","Military","Nobility_Female","Nobility_Male","Professional"],"xaxis":"x","y":[73.95498392282958,18.67145421903052,40.0,100.0,33.33333333333333,23.076923076923077],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7 ...
