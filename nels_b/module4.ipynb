# %% [markdown]
# <a href="https://colab.research.google.com/github/nelsbuhrley/CSE-450-Machine-learning/blob/main/nels_b/module4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load some test data

import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/bikes.csv")
data.head(1000)
# Out:
#         dteday    hr  casual  registered  temp_c  feels_like_c     hum  \
# 0     1/1/2011   0.0       3          13     3.0           3.0  0.7957
# 1     1/1/2011   1.0       8          30     1.7           1.7  0.8272
# 2     1/1/2011   2.0       5          26     1.9           1.9  0.8157
# 3     1/1/2011   3.0       3           9     2.5           2.5  0.7831
# 4     1/1/2011   4.0       0           1     2.0           2.0  0.8075
# ..         ...   ...     ...         ...     ...           ...     ...
# 995  2/11/2011  11.0      12          52     0.3          -2.5  0.6078
# 996  2/11/2011  12.0       7          61     2.1          -0.7  0.4598
# 997  2/11/2011  13.0      21          88     3.5           0.2  0.3365
# 998  2/11/2011  14.0      17          65     5.8           2.8  0.2676
# 999  2/11/2011  15.0      12          62     6.8           4.5  0.2159
#
#      windspeed  weathersit  season  holiday  workingday
# 0          0.8           1       1        0           0
# 1          0.8           1       1        0           0
# 2          1.1           1       1        0           0
# 3          0.8           1       1        0           0
# 4          1.1           1       1        0           0
# ..         ...         ...     ...      ...         ...
# 995        8.2           1       1        0           1
# 996        9.4           1       1        0           1
# 997       13.0           1       1        0           1
# 998       15.0           1       1        0           1
# 999       11.3           1       1        0           1
#
# [1000 rows x 12 columns]

# %%
data.describe()
# Out:
#                   hr         casual     registered         temp_c  \
# count  112475.000000  112475.000000  112475.000000  112475.000000
# mean       11.501098      90.434612     249.193625      15.376487
# std         6.921864     128.655621     258.267544       9.749467
# min         0.000000       0.000000       0.000000     -14.700000
# 25%         6.000000       7.000000      48.000000       7.600000
# 50%        12.000000      36.000000     180.000000      16.000000
# 75%        18.000000     122.000000     360.000000      23.500000
# max        23.000000    1244.000000    1702.000000      40.500000
#
#         feels_like_c            hum      windspeed     weathersit  \
# count  112475.000000  112475.000000  112475.000000  112475.000000
# mean       14.659325       0.636624      13.100614       1.405441
# std        11.428324       0.190328       7.857600       0.683450
# min       -24.000000       0.088900       0.000000       1.000000
# 25%         5.400000       0.484100       7.700000       1.000000
# 50%        16.000000       0.640900      12.200000       1.000000
# 75%        23.500000       0.798800      17.500000       2.000000
# max        49.600000       1.000000      69.800000       4.000000
#
#               season        holiday     workingday
# count  112475.000000  112475.000000  112475.000000
# mean        2.495799       0.030300       0.684312
# std         1.101152       0.171412       0.464791
# min         1.000000       0.000000       0.000000
# 25%         2.000000       0.000000       0.000000
# 50%         2.000000       0.000000       1.000000
# 75%         3.000000       0.000000       1.000000
# max         4.000000       1.000000       1.000000

# %%
# !pip install tensorflow

# Import the libraries we need
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Commonly used modules
import numpy as np

# Images, plots, display, and visualization
import matplotlib.pyplot as plt
import pandas as pd
# import seaborn as sns
# import cv2
# import IPython
# from six.moves import urllib

# print(tf.__version__)
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import root_mean_squared_error, r2_score
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.81.0)
# Requirement already satisfied: keras>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl (572.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 MB 828.9 kB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.3 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 99.1 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 44.5 MB/s eta 0:00:00
# Downloading wheel-0.47.0-py3-none-any.whl (32 kB)
# Installing collected packages: libclang, flatbuffers, wheel, h5py, google_pasta, astunparse, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.16.0
#     Uninstalling h5py-3.16.0:
#       Successfully uninstalled h5py-3.16.0
# Successfully installed astunparse-1.6.3 flatbuffers-25.12.19 google_pasta-0.2.0 h5py-3.14.0 libclang-18.1.1 tensorflow-2.21.0 wheel-0.47.0
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd

# encode time data with sin and cos
data['hour_sin'] = np.sin(data['hr']*(2.*np.pi/24))
data['hour_cos'] = np.cos(data['hr']*(2.*np.pi/24))

# encode seasons cyclically store as 8 bit intigers
data['season_sin'] = np.sin(data['season']*(2.*np.pi/4))
data['season_cos'] = np.cos(data['season']*(2.*np.pi/4))

# take the dteday and encode it as a numerice day, month, year column
data['dteday'] = pd.to_datetime(data['dteday'])
data['day'] = data['dteday'].dt.day
data['month'] = data['dteday'].dt.month
data['year'] = data['dteday'].dt.year

# encode all the hours sequencially starting with hour 1 @ midnight 1/1/2000
ref_date = pd.Timestamp('2000-01-01')
data['total_hours'] = (data['dteday'] - ref_date).dt.total_seconds() / 3600 + data['hr']

# cyclical representation of the total hours
data['time_sin'] = np.sin(data['total_hours'] * (2. * np.pi / 24))
data['time_cos'] = np.cos(data['total_hours'] * (2. * np.pi / 24))

# normalise the data
num_cols = ['temp_c', 'feels_like_c', 'hum', 'windspeed', 'total_hours','weathersit']
scaler = MinMaxScaler()
data[num_cols] = scaler.fit_transform(data[num_cols])

val = 2
## create a weather intensity column
data['weather_intensity'] = ((data['temp_c']**val + data['hum']**val + data['windspeed']**val + data['weathersit']**val)/3)**(1/val)

# Fixed typo 'regestered' -> 'registered' and added errors='ignore' to prevent KeyError on re-runs
drop_cols = ['dteday', 'hr','casual', 'registered']


display(data.drop(columns=[c for c in drop_cols if c in data.columns]).head(1000))
# Out:
#        temp_c  feels_like_c       hum  windspeed  weathersit  season  holiday  \
# 0    0.320652      0.366848  0.775766   0.011461         0.0       1        0
# 1    0.297101      0.349185  0.810339   0.011461         0.0       1        0
# 2    0.300725      0.351902  0.797717   0.015759         0.0       1        0
# 3    0.311594      0.360054  0.761936   0.011461         0.0       1        0
# 4    0.302536      0.353261  0.788717   0.015759         0.0       1        0
# ..        ...           ...       ...        ...         ...     ...      ...
# 995  0.271739      0.292120  0.569531   0.117479         0.0       1        0
# 996  0.304348      0.316576  0.407090   0.134670         0.0       1        0
# 997  0.329710      0.328804  0.271759   0.186246         0.0       1        0
# 998  0.371377      0.364130  0.196137   0.214900         0.0       1        0
# 999  0.389493      0.387228  0.139392   0.161891         0.0       1        0
#
#      workingday      hour_sin  hour_cos  season_sin    season_cos  day  month  \
# 0             0  0.000000e+00  1.000000         1.0  6.123234e-17    1      1
# 1             0  2.588190e-01  0.965926         1.0  6.123234e-17    1      1
# 2             0  5.000000e-01  0.866025         1.0  6.123234e-17    1      1
# 3             0  7.071068e-01  0.707107         1.0  6.123234e-17    1      1
# 4             0  8.660254e-01  0.500000         1.0  6.123234e-17    1      1
# ..          ...           ...       ...         ...           ...  ...    ...
# 995           1  2.588190e-01 -0.965926         1.0  6.123234e-17   11      2
# 996           1  1.224647e-16 -1.000000         1.0  6.123234e-17   11      2
# 997           1 -2.588190e-01 -0.965926         1.0  6.123234e-17   11      2
# 998           1 -5.000000e-01 -0.866025         1.0  6.123234e-17   11      2
# 999           1 -7.071068e-01 -0.707107         1.0  6.123234e-17   11      2
#
#      year  total_hours      time_sin  time_cos  weather_intensity
# 0    2011     0.000000 -1.595193e-12  1.000000           0.484686
# 1    2011     0.000009  2.588190e-01  0.965926           0.498347
# 2    2011     0.000018  5.000000e-01  0.866025           0.492286
# 3    2011     0.000027  7.071068e-01  0.707107           0.475314
# 4    2011     0.000036  8.660254e-01  0.500000           0.487802
# ..    ...          ...           ...       ...                ...
# 995  2011     0.008845  2.588190e-01 -0.965926           0.370589
# 996  2011     0.008854  1.466802e-12 -1.000000           0.303582
# 997  2011     0.008863 -2.588190e-01 -0.965926           0.269103
# 998  2011     0.008872 -5.000000e-01 -0.866025           0.272380
# 999  2011     0.008881 -7.071068e-01 -0.707107           0.256478
#
# [1000 rows x 19 columns]

# %%
y = data[['casual', 'registered']]
x = data.drop(columns=['dteday','hr','casual','registered'])

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
y_train
# Out:
#         casual  registered
# 95962       38         100
# 34637       18         173
# 5954         1           0
# 109932      15          19
# 103772     247         782
# ...        ...         ...
# 76820        2          98
# 110268      22          29
# 103694      12           6
# 860          5          62
# 15795        6           7
#
# [78732 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# fit scaler on training data
norm = MinMaxScaler().fit(X_train)

# transform training data
X_train = norm.transform(X_train)

# transform testing dataabs
X_test = norm.transform(X_test)

# %%
# len(X_train[0])

# %%
model = Sequential()
model.add(Dense(128, input_dim=len(X_train[0]), activation='relu'))
model.add(Dropout(.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(.2))
model.add(Dense(64, activation='leaky_relu'))

model.add(Dense(2, activation='relu'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 128)            │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,162 (203.76 KB)
#  Trainable params: 52,162 (203.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# opt = keras.optimizers.Adam(learning_rate=0.0001)
opt = keras.optimizers.Adam()
model.compile(loss="mean_squared_error", optimizer=opt, metrics=['mse'])

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_mse', patience=20)

history = model.fit(X_train, y_train, epochs=1000, validation_split=.35, batch_size=100, callbacks=[early_stop],shuffle=False)
# history = model.fit(train_features, train_labels, epochs=2000, verbose=0, validation_split = .2, batch_size=tester2,
#                     callbacks=[early_stop, PrintDot()])

hist = pd.DataFrame(history.history)
# Out:
# Epoch 1/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9273.7949 - mse: 9273.7949 - val_loss: 6947.7725 - val_mse: 6947.7725
# Epoch 2/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8969.1436 - mse: 8969.1436 - val_loss: 6809.7100 - val_mse: 6809.7100
# Epoch 3/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8991.7832 - mse: 8991.7832 - val_loss: 6843.4717 - val_mse: 6843.4717
# Epoch 4/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8711.0352 - mse: 8711.0352 - val_loss: 6538.1084 - val_mse: 6538.1079
# Epoch 5/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8679.4863 - mse: 8679.4863 - val_loss: 6546.7734 - val_mse: 6546.7734
# Epoch 6/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8503.1143 - mse: 8503.1143 - val_loss: 6438.1230 - val_mse: 6438.1230
# Epoch 7/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8382.9355 - mse: 8382.9355 - val_loss: 6275.9062 - val_mse: 6275.9062
# Epoch 8/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8253.5439 - mse: 8253.5439 - val_loss: 6103.5249 - val_mse: 6103.5249
# Epoch 9/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8102.2832 - mse: 8102.2837 - val_loss: 5853.9956 - val_mse: 5853.9956
# Epoch 10/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7887.1514 - mse: 7887.1514 - val_loss: 5960.7905 - val_mse: 5960.7905
# Epoch 11/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7797.4321 - mse: 7797.4321 - val_loss: 5753.7007 - val_mse: 5753.7007
# Epoch 12/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7669.4023 - mse: 7669.4023 - val_loss: 5736.4736 - val_mse: 5736.4736
# Epoch 13/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7420.1689 - mse: 7420.1689 - val_loss: 5679.0947 - val_mse: 5679.0947
# Epoch 14/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7427.1509 - mse: 7427.1509 - val_loss: 5651.3623 - val_mse: 5651.3618
# Epoch 15/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7348.0649 - mse: 7348.0649 - val_loss: 5635.4229 - val_mse: 5635.4229
# Epoch 16/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7258.9644 - mse: 7258.9658 - val_loss: 5849.0234 - val_mse: 5849.0234
# Epoch 17/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7292.3281 - mse: 7292.3281 - val_loss: 5292.2349 - val_mse: 5292.2349
# Epoch 18/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7146.2583 - mse: 7146.2583 - val_loss: 5092.6528 - val_mse: 5092.6528
# Epoch 19/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7022.0918 - mse: 7022.0918 - val_loss: 5210.1914 - val_mse: 5210.1914
# Epoch 20/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6895.4136 - mse: 6895.4136 - val_loss: 5197.0024 - val_mse: 5197.0024
# Epoch 21/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6946.2188 - mse: 6946.2188 - val_loss: 5037.5000 - val_mse: 5037.5000
# Epoch 22/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6755.0176 - mse: 6755.0176 - val_loss: 5430.6895 - val_mse: 5430.6895
# Epoch 23/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6817.8423 - mse: 6817.8423 - val_loss: 5125.0112 - val_mse: 5125.0112
# Epoch 24/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6675.1807 - mse: 6675.1807 - val_loss: 5016.0205 - val_mse: 5016.0205
# Epoch 25/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6697.0386 - mse: 6697.0386 - val_loss: 5160.7168 - val_mse: 5160.7168
# Epoch 26/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6717.7891 - mse: 6717.7891 - val_loss: 5167.3423 - val_mse: 5167.3423
# Epoch 27/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6720.8228 - mse: 6720.8228 - val_loss: 4824.4424 - val_mse: 4824.4424
# Epoch 28/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6537.1846 - mse: 6537.1846 - val_loss: 4796.6494 - val_mse: 4796.6494
# Epoch 29/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6584.5234 - mse: 6584.5225 - val_loss: 4732.9937 - val_mse: 4732.9937
# Epoch 30/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6517.6035 - mse: 6517.6035 - val_loss: 4747.7695 - val_mse: 4747.7695
# Epoch 31/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6450.3296 - mse: 6450.3296 - val_loss: 4841.7627 - val_mse: 4841.7627
# Epoch 32/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6368.8247 - mse: 6368.8247 - val_loss: 4590.1367 - val_mse: 4590.1367
# Epoch 33/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6494.9678 - mse: 6494.9678 - val_loss: 5113.0527 - val_mse: 5113.0527
# Epoch 34/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6321.1113 - mse: 6321.1113 - val_loss: 4814.7046 - val_mse: 4814.7046
# Epoch 35/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6313.2852 - mse: 6313.2852 - val_loss: 4705.7856 - val_mse: 4705.7856
# Epoch 36/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6283.3794 - mse: 6283.3794 - val_loss: 4677.5879 - val_mse: 4677.5879
# Epoch 37/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6258.0757 - mse: 6258.0757 - val_loss: 4602.3867 - val_mse: 4602.3872
# Epoch 38/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6270.8115 - mse: 6270.8115 - val_loss: 4638.1655 - val_mse: 4638.1655
# Epoch 39/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6128.6318 - mse: 6128.6318 - val_loss: 4484.1318 - val_mse: 4484.1318
# Epoch 40/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6091.7236 - mse: 6091.7236 - val_loss: 4982.3477 - val_mse: 4982.3477
# Epoch 41/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6162.2915 - mse: 6162.2915 - val_loss: 4576.4956 - val_mse: 4576.4956
# Epoch 42/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6059.6743 - mse: 6059.6743 - val_loss: 4766.9136 - val_mse: 4766.9136
# Epoch 43/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6163.9785 - mse: 6163.9785 - val_loss: 4900.3115 - val_mse: 4900.3120
# Epoch 44/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5971.8955 - mse: 5971.8955 - val_loss: 4799.8613 - val_mse: 4799.8623
# Epoch 45/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6100.9751 - mse: 6100.9751 - val_loss: 4679.9429 - val_mse: 4679.9429
# Epoch 46/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6092.1152 - mse: 6092.1152 - val_loss: 4609.8833 - val_mse: 4609.8833
# Epoch 47/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5960.9663 - mse: 5960.9663 - val_loss: 4738.6616 - val_mse: 4738.6616
# Epoch 48/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6026.0229 - mse: 6026.0229 - val_loss: 4593.1924 - val_mse: 4593.1924
# Epoch 49/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5885.3042 - mse: 5885.3042 - val_loss: 4635.9834 - val_mse: 4635.9834
# Epoch 50/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5926.1450 - mse: 5926.1450 - val_loss: 4494.5127 - val_mse: 4494.5127
# Epoch 51/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5779.8291 - mse: 5779.8291 - val_loss: 4604.7036 - val_mse: 4604.7036
# Epoch 52/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5918.1440 - mse: 5918.1440 - val_loss: 4546.1416 - val_mse: 4546.1416
# Epoch 53/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5879.4722 - mse: 5879.4722 - val_loss: 4528.7256 - val_mse: 4528.7251
# Epoch 54/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5803.5376 - mse: 5803.5376 - val_loss: 4631.8774 - val_mse: 4631.8774
# Epoch 55/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5764.6255 - mse: 5764.6260 - val_loss: 4597.9668 - val_mse: 4597.9668
# Epoch 56/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5731.7920 - mse: 5731.7920 - val_loss: 4496.2388 - val_mse: 4496.2388
# Epoch 57/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5879.6699 - mse: 5879.6704 - val_loss: 4646.3262 - val_mse: 4646.3257
# Epoch 58/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5776.5088 - mse: 5776.5088 - val_loss: 4599.6489 - val_mse: 4599.6489
# Epoch 59/1000
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5737.5703 - mse: 5737.5703 - val_loss: 4540.6768 - val_mse: 4540.6768

# %%
# h = hist
hist = hist.reset_index()
# h

# %%
def plot_history():
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error ')
    plt.plot(hist['index'], hist['mse'], label='Train Error')
    plt.plot(hist['index'], hist['val_mse'], label = 'Val Error')
    plt.legend()
    # plt.ylim([0,50])

plot_history()

# %%
predictions = np.round(model.predict(X_test),1)
# Out:
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 1s 598us/step

# %%
result = root_mean_squared_error(y_test, predictions)
result
# Out:
# 67.3290023803711

# %%
r2 = r2_score(y_test,predictions)

# %%
# ============================================================
# IMPROVED MODEL V2
# Key changes:
#  1. Robust Loss: Switched to Huber loss (robust to outliers)
#  2. Architecture: Deeper layers with 'swish' activation
#  3. Callbacks: Increased EarlyStopping patience to 50
#  4. Scaling: Keeping the target scaling (MinMax) which is essential
# ============================================================

from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import root_mean_squared_error, r2_score

# --- Scale the target variable ---
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled  = y_scaler.transform(y_test)

# --- Build improved model ---
n_features = X_train.shape[1]

improved_model = Sequential([
  Input(shape=(n_features,)),

  Dense(512, activation='swish'),
  BatchNormalization(),
  Dropout(0.2),

  Dense(256, activation='swish'),
  BatchNormalization(),
  Dropout(0.2),

  Dense(128, activation='swish'),
  BatchNormalization(),

  Dense(64, activation='swish'),
  Dense(2, activation='linear')
])

# --- Compile with Huber loss for robustness ---
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
improved_model.compile(
  loss=tf.keras.losses.Huber(),
  optimizer=opt,
  metrics=['mae', 'mse']
)

# --- Callbacks ---
early_stop = EarlyStopping(
  monitor='val_loss',
  patience=25, # More patience to allow for complex convergence
  restore_best_weights=True,
  verbose=1
)

reduce_lr = ReduceLROnPlateau(
  monitor='val_loss',
  factor=0.2,
  patience=15,
  min_lr=1e-6,
  verbose=1
)

# --- Train ---
history2 = improved_model.fit(
  X_train, y_train_scaled,
  epochs=1000, # Higher epoch limit, EarlyStopping handles the rest
  batch_size=128,
  validation_split=0.2,
  callbacks=[early_stop, reduce_lr],
  shuffle=True,
  verbose=1
)

# --- Evaluate ---
pred_scaled = improved_model.predict(X_test)
pred_orig   = y_scaler.inverse_transform(pred_scaled)
pred_orig   = np.clip(np.round(pred_orig, 1), 0, None)
rmse_improved = root_mean_squared_error(y_test, pred_orig)
r2_improved   = r2_score(y_test, pred_orig)

print(f"\n--- Improved Model Results ---")
print(f"RMSE : {rmse_improved:.4f}")
print(f"R²   : {r2_improved:.4f}")

# --- Plot training curves ---
hist2 = pd.DataFrame(history2.history).reset_index()
plt.figure(figsize=(10, 4))
plt.plot(hist2['index'], hist2['loss'], label='Train Loss (Huber)')
plt.plot(hist2['index'], hist2['val_loss'], label='Val Loss (Huber)')
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.title('Improved Model — Training History')
plt.legend(); plt.tight_layout(); plt.show()

# --- Actual vs Predicted scatter ---
pred_df = pd.DataFrame(pred_orig, columns=['pred_casual', 'pred_registered'])
pred_df['actual_casual']     = y_test['casual'].reset_index(drop=True)
pred_df['actual_registered'] = y_test['registered'].reset_index(drop=True)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for ax, actual_col, pred_col, title in zip(
    axes,
    ['actual_casual', 'actual_registered'],
    ['pred_casual', 'pred_registered'],
    ['Casual Rentals', 'Registered Rentals']
):
    mx = max(pred_df[actual_col].max(), pred_df[pred_col].max()) * 1.05
    ax.scatter(pred_df[actual_col], pred_df[pred_col], alpha=0.3, s=10)
    ax.plot([0, mx], [0, mx], 'r--')
    ax.set_xlabel(f'Actual {title}'); ax.set_ylabel(f'Predicted {title}')
    ax.set_title(title); ax.set_xlim(0, mx); ax.set_ylim(0, mx)

plt.suptitle(f'Improved Model | RMSE={rmse_improved:.2f} R²={r2_improved:.4f}')
plt.tight_layout(); plt.show()
# Out:
# Epoch 1/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0168 - mae: 0.1152 - mse: 0.0352 - val_loss: 0.0047 - val_mae: 0.0708 - val_mse: 0.0095 - learning_rate: 0.0010
# Epoch 2/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0033 - mae: 0.0584 - mse: 0.0067 - val_loss: 0.0028 - val_mae: 0.0575 - val_mse: 0.0057 - learning_rate: 0.0010
# Epoch 3/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0026 - mae: 0.0506 - mse: 0.0053 - val_loss: 0.0022 - val_mae: 0.0454 - val_mse: 0.0043 - learning_rate: 0.0010
# Epoch 4/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0022 - mae: 0.0456 - mse: 0.0044 - val_loss: 0.0015 - val_mae: 0.0355 - val_mse: 0.0029 - learning_rate: 0.0010
# Epoch 5/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0019 - mae: 0.0420 - mse: 0.0038 - val_loss: 0.0015 - val_mae: 0.0361 - val_mse: 0.0029 - learning_rate: 0.0010
# Epoch 6/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - mae: 0.0399 - mse: 0.0036 - val_loss: 0.0013 - val_mae: 0.0339 - val_mse: 0.0027 - learning_rate: 0.0010
# Epoch 7/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0016 - mae: 0.0379 - mse: 0.0033 - val_loss: 0.0011 - val_mae: 0.0299 - val_mse: 0.0022 - learning_rate: 0.0010
# Epoch 8/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0015 - mae: 0.0360 - mse: 0.0031 - val_loss: 0.0011 - val_mae: 0.0316 - val_mse: 0.0023 - learning_rate: 0.0010
# Epoch 9/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0348 - mse: 0.0029 - val_loss: 0.0012 - val_mae: 0.0321 - val_mse: 0.0024 - learning_rate: 0.0010
# Epoch 10/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0014 - mae: 0.0339 - mse: 0.0028 - val_loss: 0.0010 - val_mae: 0.0292 - val_mse: 0.0020 - learning_rate: 0.0010
# Epoch 11/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0013 - mae: 0.0324 - mse: 0.0026 - val_loss: 9.2592e-04 - val_mae: 0.0267 - val_mse: 0.0019 - learning_rate: 0.0010
# Epoch 12/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0013 - mae: 0.0318 - mse: 0.0025 - val_loss: 8.4024e-04 - val_mae: 0.0251 - val_mse: 0.0017 - learning_rate: 0.0010
# Epoch 13/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0012 - mae: 0.0311 - mse: 0.0024 - val_loss: 8.3438e-04 - val_mae: 0.0261 - val_mse: 0.0017 - learning_rate: 0.0010
# Epoch 14/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0012 - mae: 0.0305 - mse: 0.0024 - val_loss: 9.2929e-04 - val_mae: 0.0278 - val_mse: 0.0019 - learning_rate: 0.0010
# Epoch 15/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0012 - mae: 0.0302 - mse: 0.0024 - val_loss: 7.9932e-04 - val_mae: 0.0243 - val_mse: 0.0016 - learning_rate: 0.0010
# Epoch 16/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0012 - mae: 0.0297 - mse: 0.0023 - val_loss: 8.3292e-04 - val_mae: 0.0244 - val_mse: 0.0017 - learning_rate: 0.0010
# Epoch 17/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0292 - mse: 0.0023 - val_loss: 8.7485e-04 - val_mae: 0.0253 - val_mse: 0.0017 - learning_rate: 0.0010
# Epoch 18/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0289 - mse: 0.0022 - val_loss: 8.0180e-04 - val_mae: 0.0240 - val_mse: 0.0016 - learning_rate: 0.0010
# Epoch 19/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0288 - mse: 0.0023 - val_loss: 8.6762e-04 - val_mae: 0.0250 - val_mse: 0.0017 - learning_rate: 0.0010
# Epoch 20/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0285 - mse: 0.0022 - val_loss: 7.4318e-04 - val_mae: 0.0239 - val_mse: 0.0015 - learning_rate: 0.0010
# Epoch 21/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0011 - mae: 0.0283 - mse: 0.0022 - val_loss: 7.9170e-04 - val_mae: 0.0253 - val_mse: 0.0016 - learning_rate: 0.0010
# Epoch 22/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mae: 0.0277 - mse: 0.0021 - val_loss: 7.3171e-04 - val_mae: 0.0235 - val_mse: 0.0015 - learning_rate: 0.0010
# Epoch 23/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mae: 0.0277 - mse: 0.0021 - val_loss: 6.9570e-04 - val_mae: 0.0226 - val_mse: 0.0014 - learning_rate: 0.0010
# Epoch 24/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mae: 0.0275 - mse: 0.0020 - val_loss: 6.8875e-04 - val_mae: 0.0224 - val_mse: 0.0014 - learning_rate: 0.0010
# Epoch 25/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0010 - mae: 0.0276 - mse: 0.0021 - val_loss: 7.9979e-04 - val_mae: 0.0240 - val_mse: 0.0016 - learning_rate: 0.0010
# Epoch 26/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.7629e-04 - mae: 0.0267 - mse: 0.0020 - val_loss: 7.6859e-04 - val_mae: 0.0235 - val_mse: 0.0015 - learning_rate: 0.0010
# Epoch 27/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.9851e-04 - mae: 0.0270 - mse: 0.0020 - val_loss: 7.9208e-04 - val_mae: 0.0245 - val_mse: 0.0016 - learning_rate: 0.0010
# Epoch 28/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.8598e-04 - mae: 0.0270 - mse: 0.0020 - val_loss: 7.1335e-04 - val_mae: 0.0233 - val_mse: 0.0014 - learning_rate: 0.0010
# Epoch 29/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.6276e-04 - mae: 0.0265 - mse: 0.0019 - val_loss: 6.6689e-04 - val_mae: 0.0219 - val_mse: 0.0013 - learning_rate: 0.0010
# Epoch 30/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.7523e-04 - mae: 0.0266 - mse: 0.0020 - val_loss: 6.5519e-04 - val_mae: 0.0217 - val_mse: 0.0013 - learning_rate: 0.0010
# Epoch 31/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.5485e-04 - mae: 0.0265 - mse: 0.0019 - val_loss: 6.9545e-04 - val_mae: 0.0219 - val_mse: 0.0014 - learning_rate: 0.0010
# Epoch 32/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.4727e-04 - mae: 0.0263 - mse: 0.0019 - val_loss: 6.7496e-04 - val_mae: 0.0217 - val_mse: 0.0013 - learning_rate: 0.0010
# Epoch 33/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.2197e-04 - mae: 0.0261 - mse: 0.0018 - val_loss: 7.1895e-04 - val_mae: 0.0235 - val_mse: 0.0014 - learning_rate: 0.0010
# Epoch 34/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.0064e-04 - mae: 0.0258 - mse: 0.0018 - val_loss: 7.5679e-04 - val_mae: 0.0227 - val_mse: 0.0015 - learning_rate: 0.0010
# Epoch 35/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.8361e-04 - mae: 0.0256 - mse: 0.0018 - val_loss: 6.2906e-04 - val_mae: 0.0214 - val_mse: 0.0013 - learning_rate: 0.0010
# Epoch 36/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.0388e-04 - mae: 0.0258 - mse: 0.0018 - val_loss: 6.3551e-04 - val_mae: 0.0225 - val_mse: 0.0013 - learning_rate: 0.0010
# Epoch 37/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.1281e-04 - mae: 0.0259 - mse: 0.0018 - val_loss: 8.2821e-04 - val_mae: 0.0234 - val_mse: 0.0017 - learning_rate: 0.0010
# Epoch 38/1000
# 481/493 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2491e-04 - mae: 0.0262 - mse: 0.0018
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.7664e-04 - mae: 0.0255 - mse: 0.0018 - val_loss: 6.3098e-04 - val_mae: 0.0211 - val_mse: 0.0013 - learning_rate: 0.0010
# Epoch 39/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.8627e-04 - mae: 0.0238 - mse: 0.0016 - val_loss: 5.5108e-04 - val_mae: 0.0191 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 40/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.7381e-04 - mae: 0.0235 - mse: 0.0015 - val_loss: 5.5715e-04 - val_mae: 0.0194 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 41/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.6039e-04 - mae: 0.0233 - mse: 0.0015 - val_loss: 5.3848e-04 - val_mae: 0.0190 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 42/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5474e-04 - mae: 0.0233 - mse: 0.0015 - val_loss: 5.5330e-04 - val_mae: 0.0191 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 43/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4753e-04 - mae: 0.0231 - mse: 0.0015 - val_loss: 5.3885e-04 - val_mae: 0.0191 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 44/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5557e-04 - mae: 0.0232 - mse: 0.0015 - val_loss: 5.4096e-04 - val_mae: 0.0190 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 45/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5220e-04 - mae: 0.0232 - mse: 0.0015 - val_loss: 5.3980e-04 - val_mae: 0.0191 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 46/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4889e-04 - mae: 0.0231 - mse: 0.0015 - val_loss: 5.3296e-04 - val_mae: 0.0187 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 47/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.2880e-04 - mae: 0.0228 - mse: 0.0015 - val_loss: 5.5207e-04 - val_mae: 0.0193 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 48/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4687e-04 - mae: 0.0231 - mse: 0.0015 - val_loss: 5.4369e-04 - val_mae: 0.0190 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 49/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1163e-04 - mae: 0.0227 - mse: 0.0014 - val_loss: 5.3292e-04 - val_mae: 0.0188 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 50/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1915e-04 - mae: 0.0228 - mse: 0.0014 - val_loss: 5.3560e-04 - val_mae: 0.0192 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 51/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.2410e-04 - mae: 0.0228 - mse: 0.0014 - val_loss: 5.4163e-04 - val_mae: 0.0190 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 52/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.3430e-04 - mae: 0.0229 - mse: 0.0015 - val_loss: 5.3473e-04 - val_mae: 0.0187 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 53/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.3235e-04 - mae: 0.0229 - mse: 0.0015 - val_loss: 5.2796e-04 - val_mae: 0.0188 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 54/1000
# 480/493 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0630e-04 - mae: 0.0226 - mse: 0.0014
# Epoch 54: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1719e-04 - mae: 0.0227 - mse: 0.0014 - val_loss: 5.3516e-04 - val_mae: 0.0191 - val_mse: 0.0011 - learning_rate: 2.0000e-04
# Epoch 55/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9747e-04 - mae: 0.0223 - mse: 0.0014 - val_loss: 5.1632e-04 - val_mae: 0.0184 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 56/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1044e-04 - mae: 0.0224 - mse: 0.0014 - val_loss: 5.1697e-04 - val_mae: 0.0184 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 57/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8989e-04 - mae: 0.0223 - mse: 0.0014 - val_loss: 5.1599e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 58/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.0878e-04 - mae: 0.0223 - mse: 0.0014 - val_loss: 5.2014e-04 - val_mae: 0.0184 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 59/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.0963e-04 - mae: 0.0224 - mse: 0.0014 - val_loss: 5.1558e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 60/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9340e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1883e-04 - val_mae: 0.0184 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 61/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9973e-04 - mae: 0.0224 - mse: 0.0014 - val_loss: 5.1486e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 62/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9212e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1617e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 63/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9497e-04 - mae: 0.0223 - mse: 0.0014 - val_loss: 5.1388e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 64/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9556e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1389e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 65/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8528e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1515e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 66/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.0424e-04 - mae: 0.0223 - mse: 0.0014 - val_loss: 5.1339e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 67/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.0862e-04 - mae: 0.0224 - mse: 0.0014 - val_loss: 5.1320e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 68/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8898e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1449e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 69/1000
# 484/493 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0570e-04 - mae: 0.0224 - mse: 0.0014
# Epoch 69: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9284e-04 - mae: 0.0223 - mse: 0.0014 - val_loss: 5.1547e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 4.0000e-05
# Epoch 70/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9265e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1310e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 71/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9098e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1287e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 72/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8177e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1322e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 73/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8351e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1273e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 74/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9219e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1398e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 75/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8065e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1214e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 76/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.0212e-04 - mae: 0.0223 - mse: 0.0014 - val_loss: 5.1257e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 77/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8524e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1255e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 78/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1540e-04 - mae: 0.0224 - mse: 0.0014 - val_loss: 5.1264e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 79/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9109e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1301e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 80/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.7996e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1190e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 81/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.0122e-04 - mae: 0.0223 - mse: 0.0014 - val_loss: 5.1228e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 82/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8879e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1223e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 83/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9387e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1302e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 84/1000
# 488/493 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8437e-04 - mae: 0.0221 - mse: 0.0014
# Epoch 84: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9321e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1295e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 8.0000e-06
# Epoch 85/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8721e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1335e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 86/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8524e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1154e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 87/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9865e-04 - mae: 0.0223 - mse: 0.0014 - val_loss: 5.1126e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 88/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8736e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1165e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 89/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8533e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1237e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 90/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8613e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1151e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 91/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9634e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1246e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 92/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8242e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1171e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 93/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8853e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1208e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 94/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8906e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1059e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 95/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8440e-04 - mae: 0.0220 - mse: 0.0014 - val_loss: 5.1140e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 96/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.7880e-04 - mae: 0.0220 - mse: 0.0014 - val_loss: 5.1299e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 97/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9092e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1060e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 98/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9128e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1226e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 99/1000
# 486/493 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1780e-04 - mae: 0.0225 - mse: 0.0014
# Epoch 99: ReduceLROnPlateau reducing learning rate to 1e-06.
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1198e-04 - mae: 0.0224 - mse: 0.0014 - val_loss: 5.1184e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.6000e-06
# Epoch 100/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8113e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1099e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 101/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.7793e-04 - mae: 0.0220 - mse: 0.0014 - val_loss: 5.1118e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 102/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.7815e-04 - mae: 0.0220 - mse: 0.0014 - val_loss: 5.1183e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 103/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8806e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1232e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 104/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9392e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1119e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 105/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8622e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1245e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 106/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8126e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1201e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 107/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.7744e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1183e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 108/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8716e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1130e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 109/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.7102e-04 - mae: 0.0220 - mse: 0.0013 - val_loss: 5.1195e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 110/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9114e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1246e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 111/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9107e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1112e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 112/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8747e-04 - mae: 0.0220 - mse: 0.0014 - val_loss: 5.1258e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 113/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8387e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1207e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 114/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8415e-04 - mae: 0.0220 - mse: 0.0014 - val_loss: 5.1127e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 115/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9055e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1279e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 116/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.8355e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1271e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 117/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9250e-04 - mae: 0.0221 - mse: 0.0014 - val_loss: 5.1268e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 118/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9126e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1251e-04 - val_mae: 0.0183 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 119/1000
# 493/493 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 6.9249e-04 - mae: 0.0222 - mse: 0.0014 - val_loss: 5.1118e-04 - val_mae: 0.0182 - val_mse: 0.0010 - learning_rate: 1.0000e-06
# Epoch 119: early stopping
# Restoring model weights from the end of the best epoch: 94.
# 1055/1055 ━━━━━━━━━━━━━━━━━━━━ 1s 874us/step
#
# --- Improved Model Results ---
# RMSE : 47.5480
# R²   : 0.9350

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Corrected creation of the DataFrame `pred` with appropriate column names
# 'predictions' array has 2 columns (for casual and registered), so we provide two column names.
pred = pd.DataFrame(predictions, columns=['predicted_casual', 'predicted_registered'])

# Add the actual 'casual' and 'registered' values from y_test as separate columns.
# .reset_index(drop=True) is used to ensure index alignment during assignment.
pred['actual_casual'] = y_test['casual'].reset_index(drop=True)
pred['actual_registered'] = y_test['registered'].reset_index(drop=True)

# Calculate the differences for both casual and registered
pred['difference_casual'] = pred['actual_casual'] - pred['predicted_casual']
pred['difference_registered'] = pred['actual_registered'] - pred['predicted_registered']

# Display the head of the combined DataFrame to see the new structure
print(pred.head())

# Since we now have two target variables (casual, registered), we will visualize both.
fig, axes = plt.subplots(1, 2, figsize=(15, 6)) # Create two subplots

# Plot for 'casual' rentals
# Determine x and y limits dynamically for better visualization
max_val_casual = max(pred['actual_casual'].max(), pred['predicted_casual'].max())
xlims_casual = (0, max_val_casual * 1.1) if max_val_casual > 0 else (0, 1) # Ensure non-zero limit if all values are 0

sns.scatterplot(data=pred, x='actual_casual', y='predicted_casual', ax=axes[0])
axes[0].set_title('Casual Rentals: Actual vs Predicted')
axes[0].plot(xlims_casual, xlims_casual, color='r', linestyle='--') # Add diagonal line
axes[0].set_xlabel('Actual Casual')
axes[0].set_ylabel('Predicted Casual')
axes[0].set_xlim(xlims_casual)
axes[0].set_ylim(xlims_casual)

# Plot for 'registered' rentals
# Determine x and y limits dynamically
max_val_registered = max(pred['actual_registered'].max(), pred['predicted_registered'].max())
xlims_registered = (0, max_val_registered * 1.1) if max_val_registered > 0 else (0, 1)

sns.scatterplot(data=pred, x='actual_registered', y='predicted_registered', ax=axes[1])
axes[1].set_title('Registered Rentals: Actual vs Predicted')
axes[1].plot(xlims_registered, xlims_registered, color='r', linestyle='--') # Add diagonal line
axes[1].set_xlabel('Actual Registered')
axes[1].set_ylabel('Predicted Registered')
axes[1].set_xlim(xlims_registered)
axes[1].set_ylim(xlims_registered)

plt.tight_layout() # Adjust layout to prevent subplot overlap
plt.show()
# Out:
#    predicted_casual  predicted_registered  actual_casual  actual_registered  \
# 0        158.800003            362.799988            185                433
# 1        309.299988            408.700012            643                514
# 2        134.699997            337.799988            153                238
# 3         69.599998            496.600006             54                619
# 4          8.300000             66.099998              4                 26
#
#    difference_casual  difference_registered
# 0          26.199997              70.200012
# 1         333.700012             105.299988
# 2          18.300003             -99.799988
# 3         -15.599998             122.399994
# 4          -4.300000             -40.099998
